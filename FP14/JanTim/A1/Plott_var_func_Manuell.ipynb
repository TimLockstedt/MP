# %%
# <examples/doc_model_two_components.py>
import json
import pickle
import numpy as np
import matplotlib.pyplot as plt
from numpy import exp, loadtxt, pi, sqrt
from lmfit import Model
from lmfit.models import PowerLawModel, ExponentialModel, GaussianModel
from lib.to_precision import to_precision
import lmfit
from sympy import *
import sympy
from sympy.solvers import solve
from sympy import Symbol
import math
import datetime
from ipywidgets import interact, FloatText, IntText, fixed, Text
now = lambda: str(datetime.datetime.now()).replace("-", "").replace(":", "").replace(" ", "_").split(".")[0]

# %%
def save_data_to_file(filename='data.pkl'):
    # Dictionary für Parameter-Werte erstellen
    data_dict = {"x":Daten.get_x(),"xerr":Daten.get_xerr(),"y":Daten.get_y(),"yerr":Daten.get_yerr(),"XName":Daten.get_XName(),"YName":Daten.get_YName()}
    # Konvertiere alle Numpy-Arrays im Dictionary in Listen
    # dict_serializable = {key: value.tolist() if isinstance(value, np.ndarray) else value 
    #                      for key, value in data_dict.items()}
    # __x = []
    # __y = []
    # __xerr = 0
    # __yerr = 0
    # __XName = "x"
    # __YName = "y"
    # __FileName = "dataset_1"

    # Parameter als JSON-Datei speichern
    with open(filename, 'wb') as f:
        pickle.dump(data_dict, f)
    print(f"Daten wurden in {filename} gespeichert.")

# Funktion zum Einlesen der Parameter aus einer JSON-Datei
def load_data_from_file(filename='params.pkl'):
    # JSON-Datei öffnen und die Werte lesen
    with open(filename, 'rb') as f:
        data_dict = pickle.load(f)
    
    # # Konvertiere Listen zurück in Numpy-Arrays
    # data_dict= {key: np.array(value) if isinstance(value, list) else value
    #                     for key, value in dict_with_arrays.items()}

    # Geladene Werte in die Parameter setzen
    Daten.set_x(data_dict.get("x"))
    Daten.set_xerr(data_dict.get("xerr"))
    Daten.set_y(data_dict.get("y"))
    Daten.set_yerr(data_dict.get("yerr"))
    Daten.set_XName(data_dict.get("XName"))
    Daten.set_YName(data_dict.get("YName"))

    print(f"Daten wurden aus {filename} geladen.")

def finish(x,y,result, string, y_err, yLabel, xLabel):
    fig = plt.figure(figsize=(9,6), dpi=80)
    dynamic_resolution_array = np.arange(min(x),max(x), 0.001*abs(max(x)-min(x)))
    #plt.plot(x, y, 'skyblue')
    plt.plot(dynamic_resolution_array, result.eval(x = dynamic_resolution_array), 'r-', label = r'Fit: reduced $\chi^2$ =  '+str(to_precision(result.result.redchi,3)))
    plt.errorbar(
        y = y, 
        x = x, 
        yerr = y_err,
        fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, label = r'Werte'
        ) #xerr = x_err, yerr = y_err, 
    plt.legend(loc='best')

    plt.ylabel(yLabel, fontsize=20)
    plt.xlabel(xLabel, fontsize=20)

    plt.legend(fontsize=12)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.tight_layout()
    string += Daten.get_Version()
    fig.savefig(string + "_Fit.pdf")
    plt.show()

    string_fig = "\\begin{figure}[ht] \n \t\\centering \n \t\\includegraphics[width= 0.65 \\textwidth]{Fits/" + string + "_Fit.pdf} \n" \
        + "\t\\caption{"+str(string)+", Fit} \n \t\\label{fig:"+str(string)+", Fit} \n\end{figure}"
    print(string_fig)

    text_file = open(string+"_params"+".tex", "w+", encoding="utf-8")
    string_fig += "\n \\\\ \n" 
    string_fig += table_of_params(result)
    text_file.write(string_fig)
    text_file.close()

def table_of_params(result_of_fit):
    sig_num = 3
    string = "" + (
        "\\begin{table}[ht] \n"
        "\centering \n"
        "\caption{my-table} \n" 
        "\label{tab:my-table}\n"
        "\\begin{tabular}{|l|c|}\n" 
        "\hline\n"
        "Parameter Name\t&\tWert \\\\ \hline\n"
    )
    for i in result_of_fit.params:
        str_param_val = f"{float(result_of_fit.params[i].value): .{(len(str(math.floor(result_of_fit.params[i].value))) if math.floor(result_of_fit.params[i].value) != 0 else 0) +sig_num}}" 
        str_param_std = f"{float(result_of_fit.params[i].stderr): .{(len(str(math.floor(result_of_fit.params[i].stderr))) if math.floor(result_of_fit.params[i].stderr) != 0 else 0) +sig_num}}" 
        string += (
            str(i) + "\t&\t" +
            str_param_val +
            ("" if "." in str_param_val  else ".")+
            ("0"*((len(str(math.floor(result_of_fit.params[i].value))) if math.floor(result_of_fit.params[i].value) != 0 else 0) +sig_num+2 -len(f"{float(result_of_fit.params[i].value): .{(len(str(math.floor(result_of_fit.params[i].value))) if math.floor(result_of_fit.params[i].value) != 0 else 0) +sig_num}}"))) +
            " \\pm "+ 
            str_param_std +
            ("" if "." in str_param_std else ".")+
            ("0"*((len(str(math.floor(result_of_fit.params[i].stderr))) if math.floor(result_of_fit.params[i].stderr) != 0 else 0) +sig_num+2-len(f"{float(result_of_fit.params[i].stderr): .{(len(str(math.floor(result_of_fit.params[i].stderr))) if math.floor(result_of_fit.params[i].stderr) != 0 else 0) +sig_num}}"))) +
            "\\\\ \hline\n"
        )
    string += (
        "\end{tabular} \n"
        "\end{table}"
    )
    return string


class Data:
    __x = []
    __y = []
    __xerr = 0
    __yerr = 0
    __XName = "x"
    __YName = "y"
    __FileName = "dataset_1",
    __Version = ""
    __pars = None
    def set_x(self, x):
        self.__x = x
        return  
    def set_y(self, x):
        self.__y = x
        return  
    def set_yerr(self, x):
        self.__yerr = x
        return  
    def set_xerr(self, x):
        self.__xerr = x
        return  
    
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def get_xerr(self):
        return self.__xerr
    def get_yerr(self):
        return self.__yerr
    
    def set_XName(self, x):
        self.__XName = rf"{x}"
        return
    def set_YName(self, x):
        self.__YName = rf"{x}"
        return
    def get_XName(self):
        return self.__XName
    def get_YName(self):
        return self.__YName
    
    def get_FileName(self):
        return self.__FileName
    
    def set_FileName(self, x):
        self.__FileName = f"{x}"
        return
    def set_Version(self, x):
        self.__Version = f"{x}"
        return
    def get_Version(self):
        return self.__Version
    
    def get_pars(self):
        return self.__pars
    def set_pars(self,x):
        self.__pars = x
        return

def import_Data(Datei:str="dataset_1", x_err_bool = False, y_err_bool = False, Daten=Data(), skip_lower:str="0", skip_upper:str="0", x_name:str="x", y_name:str="y", save_bool=False,Save:int=0,Load:int=0,show_plot:bool=True):
    data = np.genfromtxt(Datei+".txt", skip_header = int(skip_upper), skip_footer = int(skip_lower))
    #data = np.genfromtxt(string+".txt", skip_header = 1, skip_footer = 18)

    if x_err_bool and y_err_bool:
        Daten.set_x(data[:,0])
        Daten.set_xerr(data[:, 1])
        Daten.set_y(data[:, 2])
        Daten.set_yerr(data[:, 3])
    elif x_err_bool and not y_err_bool:
        Daten.set_x(data[:,0])
        Daten.set_xerr(data[:, 1])
        Daten.set_y(data[:, 2])
        Daten.set_yerr(0)
    elif not x_err_bool and y_err_bool:
        Daten.set_x(data[:,0])
        Daten.set_xerr(0)
        Daten.set_y(data[:, 1])
        Daten.set_yerr(data[:, 2])
    elif not x_err_bool and not y_err_bool:
        Daten.set_x(data[:,0])
        Daten.set_xerr(0)
        Daten.set_y(data[:, 1])
        Daten.set_yerr(0)
    
    Daten.set_XName(x_name)
    Daten.set_YName(y_name)
    Daten.set_FileName(Datei)

    if Save != 0:
        # Aufruf der Funktion zum Speichern
        save_data_to_file(f'{Daten.get_FileName()}_daten_{Save}.pkl')
    if Load != 0:
        # Aufruf der Funktion zum Laden
        load_data_from_file(f'{Daten.get_FileName()}_daten_{Load}.pkl')
    if show_plot:
        plt.errorbar(y = Daten.get_y(), yerr = Daten.get_yerr(), x = Daten.get_x(), xerr = Daten.get_xerr(), \
            fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
            label = r'Werte')
        plt.legend(loc='best')
        plt.ylabel(Daten.get_YName(), fontsize=20)
        plt.xlabel(Daten.get_XName(), fontsize=20)
        plt.xticks(fontsize=13)
        plt.yticks(fontsize=13)
        plt.tight_layout()
        if save_bool:
            plt.savefig(Datei + f"_{Load}_Plot.pdf")
            string_fig = "\\begin{figure}[ht] \n \t\\centering \n \t\\includegraphics[width= 0.65 \\textwidth]{bilder/" + Datei + "_Plot.pdf} \n" \
                + "\t\\caption{"+str(Datei)+", Plot_log} \n \t\\label{fig:"+str(Datei)+", Plot_log} \n\end{figure}"
            print(string_fig)

        plt.show()

# %% [markdown]
# ## Interactive

# %%
Daten = Data()

interact(import_Data, Datei="A1_0V_Pedestals_Noise", 
         x_err_bool = False, 
         y_err_bool = False, 
         x_name = "Kanal [i]", 
         y_name = "Rauschen [au]", 
         Daten=fixed(Daten), 
         skip_lower = "0",
         skip_upper = "2",
         save_bool = False,
         Save=IntText(value=0,description='Daten Speichern:'), Load=IntText(value=0,description='Daten Laden:')
         )# IntText(value=0, step=1)
print()
# Out:
# interactive(children=(Text(value='A1_0V_Pedestals_Noise', description='Datei'), Checkbox(value=False, descript…

# %% [markdown]
# ## Non Interactive

# %%
Daten = Data()

import_Data(Datei="A1_0V_Pedestals_Noise", 
            x_err_bool = False, 
            y_err_bool = False, 
            x_name = "Kanal [i]", 
            y_name = "Raushen [au]",  
            Daten=Daten, 
            skip_lower = "0",
            skip_upper = "2",
            save_bool = False,
            Save=0, Load=0
            )

# %% [markdown]
# ## Error Band

# %%
from uncertainties import unumpy as up
# 160*10**(-6)/np.sqrt(12)
lst_y_ges = []
lst_y_part = []
Voltage_lst = [0,1,2,5,10,20,30,39,40,60,80,100]
for voltage in Voltage_lst:
    Daten = Data()

    import_Data(Datei=f"A1_{voltage}V_Pedestals_Noise", 
                x_err_bool = False, 
                y_err_bool = False, 
                x_name = "Kanal [i]", 
                y_name = "Rauschen [AU]",  
                Daten=Daten, 
                skip_lower = "0",
                skip_upper = "2",
                save_bool = False,
                Save=0, Load=0, show_plot=False
                )
    y_Ges = up.uarray(Daten.get_y(), (np.sqrt(np.ones(np.shape(Daten.get_y())[0]))))
    y_part = up.uarray(Daten.get_y()[40:80], (np.sqrt(np.ones(np.shape(Daten.get_y()[40:80])[0]))))
    lst_y_ges.append(np.mean(y_Ges)) 
    lst_y_part.append(np.mean(y_part))
lst_y_ges
# Out:
# [10.438223718749999+/-0.08838834764831845,
#  7.559192789062499+/-0.08838834764831845,
#  6.899576625000001+/-0.08838834764831845,
#  6.096351453125002+/-0.08838834764831845,
#  4.798053796874998+/-0.08838834764831845,
#  4.381815703125001+/-0.08838834764831845,
#  4.152631296875+/-0.08838834764831845,
#  4.1026608359375+/-0.08838834764831845,
#  4.077293031250001+/-0.08838834764831845,
#  3.9912622734375005+/-0.08838834764831845,
#  4.0077907421875+/-0.08838834764831845,
#  3.9993904921875+/-0.08838834764831845]

# %%
lst_y_part
# Out:
# [10.37709225+/-0.15811388300841903,
#  7.55840745+/-0.15811388300841903,
#  6.841995825+/-0.15811388300841903,
#  6.019794275+/-0.15811388300841903,
#  4.757110000000001+/-0.15811388300841903,
#  4.2995684249999995+/-0.15811388300841903,
#  4.057956024999999+/-0.15811388300841903,
#  4.0491279+/-0.15811388300841903,
#  4.03028855+/-0.15811388300841903,
#  3.893916700000001+/-0.15811388300841903,
#  3.9622839749999996+/-0.15811388300841903,
#  3.9622648499999995+/-0.15811388300841903]

# %%
np.mean(Daten.get_y()), np.median(Daten.get_y())
# Out:
# (3.9993904921875005, 3.992868)

# %%
def Std_error(Daten):
    med_noise = np.mean(Daten.get_y())
    sigma = 0

    for noise in Daten.get_y():
        sigma += (noise - med_noise)**2

    sigma = sigma/(Daten.get_y().shape[0]-1)
    std_ges = np.sqrt(sigma)
    return std_ges

def Std_error_part(Daten):
    med_noise = np.mean(Daten.get_y()[40:80])
    sigma = 0

    for noise in Daten.get_y()[40:80]:
        sigma += (noise - med_noise)**2

    sigma = sigma/(Daten.get_y()[40:80].shape[0]-1)
    std_ges = np.sqrt(sigma)
    return std_ges

# %%
error_1 = Std_error(Daten)  # Constant error of 160*10**(-6)/np.sqrt(12)
error_2 = Std_error_part(Daten) 
# Median alle 



x_1 = Daten.get_x()
y_1 = np.ones(np.shape(Daten.get_y()))*np.mean(Daten.get_y())
string = Daten.get_FileName()
# mean 40-80
x_2 = Daten.get_x()[40:80]
y_2 = np.ones(np.shape(Daten.get_y()[40:80]))*np.mean(Daten.get_y()[40:80])


fig = plt.figure(figsize=(8, 6))
plt.errorbar(y = Daten.get_y(), yerr = Daten.get_yerr(), x = Daten.get_x(), xerr = Daten.get_xerr(), \
    fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
    label = r'Werte')

plt.fill_between(x_1, y_1 - error_1, y_1 + error_1, alpha=0.2)
plt.plot(x_1, y_1, label=f'mean {np.mean(Daten.get_y()): .5}')

plt.fill_between(x_2, y_2 - error_2, y_2 + error_2, alpha=0.2)
plt.plot(x_2, y_2, label=f'mean {np.mean(Daten.get_y()[40:80]): .5}')
#plt.plot(x_fit, y_fit, label="Modell", color='red')
plt.legend()
plt.ylabel(Daten.get_YName(), fontsize=20)
plt.xlabel(Daten.get_XName(), fontsize=20)
# plt.title('Models')
plt.tight_layout()
string += Daten.get_Version()
fig.savefig(string + "_ErrorBand.pdf")

# %%
Voltage_lst = [0,1,2,5,10,20,30,39,40,60,80,100]
string_fig = ""
errors_1 = []
errors_2 = []
med_1 = []
med_2 = []
for voltage in Voltage_lst:
    Daten = Data()

    import_Data(Datei=f"A1_{voltage}V_Pedestals_Noise", 
                x_err_bool = False, 
                y_err_bool = False, 
                x_name = "Kanal [i]", 
                y_name = "Rauschen [AU]",  
                Daten=Daten, 
                skip_lower = "0",
                skip_upper = "2",
                save_bool = False,
                Save=0, Load=0, show_plot=False
                )
    error_1 = Std_error(Daten)  # Constant error of 160*10**(-6)/np.sqrt(12)
    error_2 = Std_error_part(Daten) 
    error_1 = 1/np.sqrt(Daten.get_x().shape[0])  # Constant error of 160*10**(-6)/np.sqrt(12)
    error_2 = 1/np.sqrt(Daten.get_x()[40:80].shape[0]) 
    
    errors_1.append(error_1)
    errors_2.append(error_2)
    med_1.append(np.mean(Daten.get_y()))
    med_2.append(np.mean(Daten.get_y()[40:80]))
    # mean alle 
    x_1 = Daten.get_x()
    y_1 = np.ones(np.shape(Daten.get_y()))*np.mean(Daten.get_y())
    string = Daten.get_FileName()
    # mean 40-80
    x_2 = Daten.get_x()[40:80]
    y_2 = np.ones(np.shape(Daten.get_y()[40:80]))*np.mean(Daten.get_y()[40:80])


    fig = plt.figure(figsize=(8, 6))
    plt.errorbar(y = Daten.get_y(), yerr = Daten.get_yerr(), x = Daten.get_x(), xerr = Daten.get_xerr(), \
        fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
        label = r'Werte')

    plt.fill_between(x_1, y_1 - error_1, y_1 + error_1, alpha=0.2)
    plt.plot(x_1, y_1, label=f'Mittelwert {np.mean(Daten.get_y()): .5}')

    plt.fill_between(x_2, y_2 - error_2, y_2 + error_2, alpha=0.2)
    plt.plot(x_2, y_2, label=f'Mittelwert {np.mean(Daten.get_y()[40:80]): .5}')
    #plt.plot(x_fit, y_fit, label="Modell", color='red')
    plt.legend()
    plt.ylabel(Daten.get_YName(), fontsize=20)
    plt.xlabel(Daten.get_XName(), fontsize=20)
    # plt.title('Models')
    plt.tight_layout()
    string += Daten.get_Version()
    fig.savefig(string + "_ErrorBand.pdf")

    string_fig += "\\begin{figure}[ht] \n \t\\centering \n \t\\includegraphics[width= 0.65 \\textwidth]{bilder/" + Daten.get_FileName() + "_ErrorBand.pdf} \n" \
            + "\t\\caption{"+str(Daten.get_FileName())+", ErrorBand} \n \t\\label{fig:"+str(Daten.get_FileName())+", ErrorBand} \n\end{figure} \n \n \n"
        
print(string_fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 21
#       8 Daten = Data()
#      10 import_Data(Datei=f"A1_{voltage}V_Pedestals_Noise",
#      11             x_err_bool = False,
#      12             y_err_bool = False,
#    (...)
#      19             Save=0, Load=0, show_plot=False
#      20             )
# ---> 21 error_1 = Std_error(Daten)  # Constant error of 160*10**(-6)/np.sqrt(12)
#      22 error_2 = Std_error_part(Daten)
#      23 error_1 = 1/np.sqrt(Daten.get_x().shape[0])  # Constant error of 160*10**(-6)/np.sqrt(12)
#
# NameError: name 'Std_error' is not defined

# %%
from lmfit.models import PowerLawModel, ExponentialModel, GaussianModel, Model, ConstantModel

mod = ConstantModel()#GaussianModel(prefix = "a")+GaussianModel(prefix = "b")
pars = mod.make_params()


Voltage_lst = [0,1,2,5,10,20,30,39,40,60,80,100]
string_fig = ""
errors_1 = []
errors_2 = []
med_1 = []
med_2 = []
for voltage in Voltage_lst:
    Daten = Data()

    import_Data(Datei=f"A1_{voltage}V_Pedestals_Noise", 
                x_err_bool = False, 
                y_err_bool = False, 
                x_name = "Kanal [i]", 
                y_name = "Rauschen [AU]",  
                Daten=Daten, 
                skip_lower = "0",
                skip_upper = "2",
                save_bool = False,
                Save=0, Load=0, show_plot=False
                )


    result = mod.fit(Daten.get_y(), pars, x=Daten.get_x())
    result_2 = mod.fit(Daten.get_y()[40:80], pars, x=Daten.get_x()[40:80])

    error_1 = [result.params[i].stderr for i in result.params][0]
    error_2 = [result_2.params[i].stderr for i in result.params][0]
    errors_1.append(error_1)
    errors_2.append(error_2)
    med_cur_1 = [result.params[i].value for i in result.params][0]
    med_cur_2 = [result_2.params[i].value for i in result.params][0]
    med_1.append(med_cur_1)
    med_2.append(med_cur_2)



    x_1 = Daten.get_x()
    y_1 = np.ones(np.shape(Daten.get_y()))*med_cur_1
    
    string = Daten.get_FileName()
    # mean 40-80
    x_2 = Daten.get_x()[40:80]
    y_2 = np.ones(np.shape(Daten.get_y()[40:80]))*med_cur_2


    fig = plt.figure(figsize=(8, 6))
    plt.errorbar(y = Daten.get_y(), yerr = Daten.get_yerr(), x = Daten.get_x(), xerr = Daten.get_xerr(), \
        fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
        label = r'Werte')

    plt.fill_between(x_1, y_1 - error_1, y_1 + error_1, alpha=0.2)
    plt.plot(x_1, y_1, label=f'Mittelwert {med_cur_1: .5}'+r"$ \pm$"+f"{error_1: .3}")

    plt.fill_between(x_2, y_2 - error_2, y_2 + error_2, alpha=0.2)
    plt.plot(x_2, y_2, label=f'Mittelwert {med_cur_2: .5}'+r"$ \pm$"+f"{error_2: .3}")
    #plt.plot(x_fit, y_fit, label="Modell", color='red')
    plt.legend()
    plt.ylabel(Daten.get_YName(), fontsize=20)
    plt.xlabel(Daten.get_XName(), fontsize=20)
    # plt.title('Models')
    plt.tight_layout()
    string += Daten.get_Version() + "_FitVar"
    fig.savefig(string + "_ErrorBand.pdf")

    string_fig += "\\begin{figure}[ht] \n \t\\centering \n \t\\includegraphics[width= 0.65 \\textwidth]{bilder/" + string + "_ErrorBand.pdf} \n" \
            + "\t\\caption{"+str(string)+", ErrorBand} \n \t\\label{fig:"+str(string)+", ErrorBand} \n\end{figure} \n \n \n"
        
print(string_fig)
# Out:
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_0V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_0V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_0V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_1V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_1V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_1V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_2V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_2V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_2V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_5V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_5V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_5V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_10V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_10V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_10V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_20V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_20V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_20V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_30V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_30V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_30V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_39V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_39V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_39V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_40V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_40V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_40V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_60V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_60V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_60V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_80V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_80V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_80V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}
#
#
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_100V_Pedestals_Noise_FitVar_ErrorBand.pdf}
# 	\caption{A1_100V_Pedestals_Noise_FitVar, ErrorBand}
#  	\label{fig:A1_100V_Pedestals_Noise_FitVar, ErrorBand}
# \end{figure}

# %%
for i in result.params:
    result.params[i].stderr
# Out:
# 10.43822371875

# %%
fig = plt.figure(figsize=(8, 6))
plt.errorbar(y = med_1, yerr = errors_1, x = Voltage_lst, xerr = 0, \
    fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
    label = r'Mittelwert des Rauschens, Gesamt')
plt.errorbar(y = med_2, yerr = errors_2, x = Voltage_lst, xerr = 0, \
    fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'red', zorder = 0, \
    label = r'Mittelwert des Rauschens, zwischen 40-80')
plt.legend()
plt.ylabel("Rauschen [AU]", fontsize=20)
plt.xlabel("Spannung [V]", fontsize=20)
# plt.title('Models')
plt.tight_layout()
fig.savefig("A1_Ges_MedAsFuncOfVoltage_FitVar.pdf")

string_fig = "\\begin{figure}[ht] \n \t\\centering \n \t\\includegraphics[width= 0.65 \\textwidth]{bilder/" + "A1_Ges_MedAsFuncOfVoltage_FitVar.pdf} \n" \
        + "\t\\caption{A1 Ges Mittelwert as a function of Voltage, ErrorBand} \n \t\\label{fig:A1 Ges Mittelwert as a function of Voltage, ErrorBand} \n\end{figure}"
print(string_fig)
# Out:
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{bilder/A1_Ges_MedAsFuncOfVoltage_FitVar.pdf}
# 	\caption{A1 Ges Mittelwert as a function of Voltage, ErrorBand}
#  	\label{fig:A1 Ges Mittelwert as a function of Voltage, ErrorBand}
# \end{figure}

# %%
errors_2
# Out:
# [0.07293426951665716,
#  0.06369828689905581,
#  0.05300682601312278,
#  0.02945101182527109,
#  0.034887019258935524,
#  0.029176981139467765,
#  0.027426545465652936,
#  0.03096598988400944,
#  0.02764072539886495,
#  0.030763160900026502,
#  0.025732186351933046,
#  0.032577325840801835]

# %%
med_2
# Out:
# [10.377092250392852,
#  7.558407450286146,
#  6.841995825259026,
#  6.0197942752278975,
#  4.757110000180096,
#  4.299568425,
#  4.057956025087686,
#  4.049127900073277,
#  4.030288550060111,
#  3.8939167,
#  3.9622839750371535,
#  3.9622648500410946]

# %% [markdown]
# ## Fit-Funktionen festlegen

# %%
from sympy import oo, Symbol, integrate, Function
def convolve(f, g, t, lower_limit=-oo, upper_limit=oo):
    tau = Symbol('__very_unlikely_name__', real=True)
    return integrate(Function(f).subs(t, tau) * Function(g).subs(t, t - tau), 
                     (tau, lower_limit, upper_limit))

def Gauss(x,sigma=1,mu=1):
    return 1/(sigma*np.sqrt(2*math.pi))*np.exp(-1/2*(x-mu/sigma)**2)

def Landau(x):
    t = Symbol('__very_unlikely_name__', real=True)
    return integrate(1/(math.pi)*np.exp(-x*np.ln(t-x*t))*np.sin(math.pi*t) ,
                     (t, 0, oo))

def Model_test(x):
    return(convolve(Gauss, Landau, x))

# %%
from lmfit.models import PowerLawModel, ExponentialModel, GaussianModel, Model, ConstantModel
# import pylandau

# def plot_func(x, mpv=1, eta=1, sigma=1, A=1):
#     return pylandau.langau(x, mpv, eta, sigma, A)

def plot_func(x,a=1):
    return a

    
mod = ConstantModel()#GaussianModel(prefix = "a")+GaussianModel(prefix = "b")

pars = mod.make_params()

pars
# Out:
# Parameters([('c', <Parameter 'c', value=0.0, bounds=[-inf:inf]>)])

# %% [markdown]
# ## Parameter Festlegen

# %%
# Funktion zum Speichern der Parameter in einer JSON-Datei
def save_params_to_file(params, filename='params.json'):
    # Dictionary für Parameter-Werte erstellen
    params_dict = {name: param.value for name, param in params.items()}
    
    # Parameter als JSON-Datei speichern
    with open(filename, 'w') as f:
        json.dump(params_dict, f)
    print(f"Parameter wurden in {filename} gespeichert.")

# Funktion zum Einlesen der Parameter aus einer JSON-Datei
def load_params_from_file(params, filename='params.json'):
    # JSON-Datei öffnen und die Werte lesen
    with open(filename, 'r') as f:
        params_dict = json.load(f)

    # Geladene Werte in die Parameter setzen
    for name, value in params_dict.items():
        if name in params:
            params[name].value = value
        else:
            print(f"Warnung: Parameter {name} existiert nicht im aktuellen Modell.")

    print(f"Parameter wurden aus {filename} geladen.")

def update_model(Save:int=0, Load:int=0, **params):
    # Setze die Werte der Parameter
    for name, value in params.items():
        pars[name].value = value
    if Save != 0:
        # Aufruf der Funktion zum Speichern
        save_params_to_file(pars, f'{Daten.get_FileName()}_params_{Save}.json')
        Daten.set_Version(Save)
    if Load != 0:
        load_params_from_file(pars, f'{Daten.get_FileName()}_params_{Load}.json')
        Daten.set_Version(Load)

    # Berechne Modell mit aktuellen Parametern
    x = Daten.get_x()
    x_fit = np.arange(x.min(), x.max(), (x.max() - x.min())/10000)
    y_fit = mod.eval(pars, x=x_fit)

    # Plotten der Daten und des Modells
    plt.figure(figsize=(8, 6))
    plt.errorbar(y = Daten.get_y(), yerr = Daten.get_yerr(), x = Daten.get_x(), xerr = Daten.get_xerr(), \
        fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
        label = r'Werte')
    
    plt.plot(x_fit, y_fit, label="Modell", color='red')
    plt.legend()
    plt.ylabel(Daten.get_YName(), fontsize=20)
    plt.xlabel(Daten.get_XName(), fontsize=20)
    plt.title('Models')
    result = mod.fit(Daten.get_y(), pars, x=Daten.get_x())
    Daten.set_pars(result)
    dynamic_resolution_array = np.arange(min(Daten.get_x()),max(Daten.get_x()), 0.001*abs(max(Daten.get_x())-min(Daten.get_x())))
    plt.plot(dynamic_resolution_array, result.eval(x = dynamic_resolution_array), 'b-', label = r'Fit: reduced $\chi^2$ =  '+str(to_precision(result.result.redchi,3)))
    plt.tight_layout()
    plt.show()

# %%
Daten.get_yerr(), Daten.get_xerr()
# Out:
# (0, 0)

# %%
param_widgets = {}
for param_name, param in pars.items():
    param_widgets[param_name] = IntText(value=param.value,
                                            step=0.1,
                                            description=param_name)

# Interaktive Anzeige mit automatisch generierten Slidern
interact(update_model, Save=IntText(value=0), Load=IntText(value=0), **param_widgets)
print()
# Out:
# interactive(children=(IntText(value=0, description='Save'), IntText(value=0, description='Load'), IntText(valu…

# %%
result = mod.fit(Daten.get_y(), pars, x=Daten.get_x())
dynamic_resolution_array = np.arange(min(Daten.get_x()),max(Daten.get_x()), 0.001*abs(max(Daten.get_x())-min(Daten.get_x())))

plt.figure(figsize=(8, 6))
plt.errorbar(y = Daten.get_y(), yerr = Daten.get_yerr(), x = Daten.get_x(), xerr = Daten.get_xerr(), \
    fmt = 'o', markersize = 3.5, alpha = 1, mfc = 'black', c = 'skyblue', zorder = 0, \
    label = r'Werte')

#plt.plot(x_fit, y_fit, label="Modell", color='red')
plt.legend()
plt.ylabel(Daten.get_YName(), fontsize=20)
plt.xlabel(Daten.get_XName(), fontsize=20)
plt.title('Models')

plt.plot(dynamic_resolution_array, result.eval(x = dynamic_resolution_array), 'r-', label = r'Fit: reduced $\chi^2$ =  '+str(to_precision(result.result.redchi,3)))

plt.show()

# %%
Daten.get_pars()
# Out:
# <h2>Fit Result</h2> <p>Model: Model(constant)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>128</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>1</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 28.6065850</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.22524870</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-189.794346</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-186.942316</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.00000000</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>c</td><td style='text-align:left'> 10.4382237</td><td style='text-align:left'> 0.04194944</td><td style='text-align:left'>(0.40%)</td><td style='text-align:left'>0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
weights = 1/np.sqrt(Daten.get_y())
weights[weights == np.inf] = 0
Daten.set_yerr(weights)

result = mod.fit(Daten.get_y(), pars, x=Daten.get_x(),weights=weights)
finish(Daten.get_x(),Daten.get_y(),result, Daten.get_FileName(), Daten.get_yerr(), Daten.get_YName(), Daten.get_XName())
# Out:
# \begin{figure}[ht]
#  	\centering
#  	\includegraphics[width= 0.65 \textwidth]{Fits/A1_0V_Pedestals_Noise_Fit.pdf}
# 	\caption{A1_0V_Pedestals_Noise, Fit}
#  	\label{fig:A1_0V_Pedestals_Noise, Fit}
# \end{figure}
